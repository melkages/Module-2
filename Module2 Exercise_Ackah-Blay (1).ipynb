# %% [markdown]
# ## Exercises
# ### Write the pseudocode for these problems.
#
# #### Define the problem by constructing an IPO diagram showing input, output, and processing steps
# Ask yourself
# - What control structures (sequence, selection and repetition) are required?
# - What variables are required?
#
# Show a check of your solution with **test data** for at least **two valid test cases**
# If you use the numbers provided in the example then the correct pseudocode will calculate the same result.

# %% [markdown]
# #### 1. Find the average score
# A program is needed to prompt the user operator for exam scores, calculate the average score and display the result to the screen. The average score is calculated as the sum of the scores divided by the number of scores.

# %% [markdown]
# Type Markdown and LaTeX:  𝛼2

# %% [markdown]
# Input:
# Ask the user to enter the text scores
#
# Process:
# Add the text scores and divide the total by the number of scores (total/number of scores)
#
# Ouput
# Display the quotient as the average of the scores
#
#
# Pseudocode:
#
# Ask the user for the number of scores
#
# Store the number of scores in the variable "scores"
#
# Create a for loop with i=1, <=scores, i++
#
# Create a float variable "total"
#
# In each ilteration, ask the user to enter a text score
#
# The new scores are added to total which is initially set to O
#
# After the loop ends, create a new variable called "average"
#
# Divide "total" by "scores"
#
# The result is stored in the "average" variable
#
# Display the ouput variable for the user
#
#
#
#
# SAMPLE OUTPUT 1:
#
# Computer: How many test scores are there
#
# User: 4
#
# Computer: for loop runs 1st time
#
# User: Enters 100
#
# Computer: for loop runs 2nd time
#
# User: Enters 90
#
# Computer: for loop runs 3rd time
#
# User: Enters 95
#
# Computer: for loop runs 4th time
#
# User: Enters: 93
#
# Computer: Calculates the total (378) and divides by 4. The quotient 94.5 is stored in the "average" variable
#
# Computer: The average is 94.5
#
#
#
#
# SAMPLE OUTPUT 2:
#
# Computer: How many test scores are there
#
# User: 6
#
# Computer: for loop runs 1st time
#
# User: Enters 73
#
# Computer: for loop runs 2nd time
#
# User: Enters 100
#
# Computer: for loop runs 3rd time
#
# User: Enters 99
#
# Computer: for loop runs 4th time
#
# User: Enters: 86
#
# Computer: for loop runs 5th time
#
# User: Enters: 80
#
# Computer: for loop runs 6th time
#
# User: Enters: 98
#
# Computer: for loop runs 7th time
#
# User: Enters: 99
#
# Computer: Calculates the total (635) and divides by 7. The quotient 90.7 is stored in the "average" variable
#
# Computer: The average is 90.7

# %% [markdown]
# #### 2. How much water runs off a roof in a rain storm?
# To calculate the runoff from any given rainfall: Take the dimensions of the footprint of the roof and convert them to inches. (So, a 50' x 20' roof is 600" x 240"). Multiply the roof dimensions by the number of inches of rainfall. As an example, 600" x 240" x 1" = 144,000 cubic inches of water for an inch of rainfall. Divide that result by 231 to get the number of gallons (because 1 gallon = 231 cubic inches). (144,000/231 = 623.38).

# %% [markdown]
# Type Markdown and LaTeX:  𝛼2

# %% [markdown]
# Pseudocode:
#
# Ask the user to enter the dimensions for the width and length of the roof in feet (ft)
#
# Convert to inches by:
#
# Multiply the value for the length of the roof by 12 and store in a new variable "length_in_inches"
#
# Multiply the value for the width of the rood by 12 and store in a ew variable "width_in_inches"
#
# Create a new variable "inches_of_rain"
#
# Ask the user to enter the amount of rainfall in inches
#
# Create a new variable "cubic_inches"
#
# Multiply inches_of_rain by length_in_inches by width_in_inches
#
# The product is stored in the "cubic_inches" variable
#
# Create a new variable "gallons_of_rain"
#
# Divide "cubic_inches" by 231 and store the result in the float variable "gallons_of_rain"
#
# Display the amount of rain by outputing "gallons_of_rain": (Eg: print(gallons_of_rain + " gallons of rain ran off the roof.")
#
#
#
#
#
# SAMPLE OUTPUT 1:
#
# Computer: Enter the dimensions for the width and length
#
# User: 10' * 5'
#
# Computer: length_in_inches = 120" * 60"
#
# Computer: Enter the amount of rainfall in inches
#
# User: 3"
#
# Computer: 21600 / 231 = 93.51
#
# Computer: 93.51 gallons of rain ran off the roof
#
#
#
#
#
# SAMPLE OUTPUT 1:
#
# Computer: Enter the dimensions for the width and length
#
# User: 438' * 245'
#
# Computer: length_in_inches = 5256" * 2940"
#
# Computer: Enter the amount of rainfall in inches
#
# User: 7"
#
# Computer: 108,168,480 / 231 = 468261.82
#
# Computer: 468261.82 gallons of rain ran off the roof

# %% [markdown]
# #### 3. Process customer record
# A program is required to read a customer’s name, a purchase amount and a tax code. The tax code has been validated and will be one of the following: 0 tax exempt (0%) 1 state sales tax only (3%) 2 federal and state sales tax (5%) 3 special sales tax (7%) The program must then compute the sales tax and the total amount due,and print the customer’s name, purchase amount, sales tax and total amount due.

# %% [markdown]
# Type Markdown and LaTeX:  𝛼2

# %% [markdown]
# Pseudocode
#
# Create a string variable "Customer_Name" to store the customer's name
#
# Create a float variable called state_tax_only = 0.03
#
# Create a float variable called federal_and_state = 0.05
#
# Create a float variable called speacial_tax = 0.07
#
# Create a float variable called purchase_amount
#
# Create a float variable called total
#
# Ask the user for the purchase amount and store in "purchase_amount"
#
# Check the tax code
#
# Create and if/else statement
#
# If no tax applies, total = purchae_amount
#
# Else If it is state tax, total = (0.03 * purchase_amount) + purchase amount
#
# Else If it is federal and state tax, total = (0.05 * purchase_amount) + purchase amount
#
# Else If it is special tax, total = (0.07 * purchase_amount) + purchase amount
#
# Output the customer's name
#
# Ouput the customer's total amount
#
#
#
#
# SAMPLE OUTPUT 1:
#
# Computer: Enter your name
#
# User: Jenny
#
# Computer: Enter your purchase amount]
#
# User: 499.99
#
# Computer: Checks and it is state tax only
#
# Computer: Executes option 2
#
# Computer: 499.99 * 0.03 = 15.00
#
# Compuuter: Calculates total. 499.99 + 15.00 = 514.99
#
# Computer: Jenny
#
# Computer: Total Amount: 514.99
#
#
#
#
#
# SAMPLE OUTPUT 2:
#
# Computer: Enter your name
#
# User: Nick
#
# Computer: Enter your purchase amount]
#
# User: 37.83
#
# Computer: Checks and no tax applies (0% tax)
#
# Computer: Executes option 1
#
# Compuuter: Calculates total. 37.83
#
# Computer: Nick
#
# Computer: Total Amount: 37.83

# %% [markdown]
# #### 4. Calculate employee's pay
# A program is required by a company to read an employee’s number, pay rate and the number of hours worked in a week. The program is then to validate the pay rate field and the hours worked field and, if valid, compute the employee’s weekly pay and then print it and the input data.
#
# Validation: According to the company’s rules, the maximum hours an employee can work per week is 60 hours, and the maximum hourly rate is $25.00 per hour. If the hours worked field or the hourly rate field is out of range, the input data and an appropriate message are to be printed and the employee’s weekly pay is not to be calculated.
#
# Weekly pay calculation: Weekly pay is calculated as hours worked times pay rate. If more than 35 hours are worked, payment for the overtime hours worked is calculated at time-and-a-half.

# %% [markdown]
# Type Markdown and LaTeX:  𝛼2

# %% [markdown]
# PSEUCODE
#
# Create variable to store employee's number
#
# Create variable to store employee's hours worked
#
# Create variable to store employee's pay rate
#
# Create variable to store employee's total pay
#
#
# Ask the employee for their number
#
# Ask the employee for their hours worked
#
# Ask the employee for their pay rate
#
# Create an if/else statement
#
# If employee's hours worked is greater than 0 but less than or equal to 35 AND pay rate is less than or equal to 25, ask employee for hours worked, ask employee for pay rate, multiply pay rate by hours worked.
# Display the product/final pay
#
# Else if employee's hours worked is greater than 35  AND pay rate is less than or equal to 25, ask employee for hours worked, ask employee for pay rate, multiply pay rate by hours worked. Multiply pay rate by 35. Create a new variable "initial_pay." Subtract 35 from hours worked. Divide the difference by 1.5. Round the answer to a whole number. Store the quotient in a new varibale "new_hours_worked". Multiply new_hours_worked by pay rate and store results in new_pay. Add initial_pay and new_pay. Store the sum in the total pay variable. Display the total pay
#
# Else employee's hours worked is greater than 60, OR, pay rate is supposedly out of range, display "Sorry, you might have entered incorrect figures for your hours worked or pay rate. See the manager as soon as possible."
#
#
#
# SAMPLE OUTPUT 1:
#
# Computer: Enter your account number
#
# Employee: 04947
#
# Computer: Enter your hours worked
#
# Employee: 40
#
# Computer: Sorry, you might have entered incorrect figures for your hours worked or pay rate. See the manager as soon as possible.
#
#
#
# SAMPLE OUTPUT 2:
#
# Computer: Enter your account number
#
# Employee: 03921
#
# Computer: Enter your hours worked
#
# Employee: 30
#
# Computer: Enter your pay rate
#
# Employee: 24.50
#
# Computer: 24.50 * 30
#
# Computer: Your pay is 735.00
